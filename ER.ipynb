# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('happyBoy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.40it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 3.276996301777109e-14,
#    'disgust': 1.840850128181901e-17,
#    'fear': 8.009296004196642e-09,
#    'happy': 100.0,
#    'sad': 1.8120116409940656e-11,
#    'surprise': 4.58431740919113e-11,
#    'neutral': 8.096098014220843e-07},
#   'dominant_emotion': 'happy',
#   'region': {'x': 192, 'y': 177, 'w': 418, 'h': 418},
#   'age': 22,
#   'gender': {'Woman': 1.2210513465106487, 'Man': 98.7789511680603},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.003571631168597378,
#    'indian': 0.027857001987285912,
#    'black': 0.0005082378720544511,
#    'white': 86.19005084037781,
#    'middle eastern': 8.585499227046967,
#    'latino hispanic': 5.192514508962631},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cv2.CascadeClassifier
# Out:
# cv2.CascadeClassifier

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)


#draw a rectangle around the faces
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w , y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions[0]['dominant_emotion'], (x, y+h+30), font, 2, (0, 0, 255), 2, cv2.LINE_4)
cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('angry_girl.jpg')

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  6.95it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 82.5016757843881,
#    'disgust': 0.0009228542503839414,
#    'fear': 0.30796240137965664,
#    'happy': 0.0011593634990639725,
#    'sad': 10.36858584063222,
#    'surprise': 0.006926405232790978,
#    'neutral': 6.812757186560966},
#   'dominant_emotion': 'angry',
#   'region': {'x': 477, 'y': 131, 'w': 121, 'h': 121},
#   'age': 28,
#   'gender': {'Woman': 99.99457597732544, 'Man': 0.005426990537671372},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 1.8785171196356032e-07,
#    'indian': 8.810411844528687e-08,
#    'black': 7.799702181864043e-11,
#    'white': 99.9835729598999,
#    'middle eastern': 0.00680689699947834,
#    'latino hispanic': 0.009620204946259037},
#   'dominant_race': 'white'}]

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cv2.CascadeClassifier
# Out:
# cv2.CascadeClassifier

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions[0]['dominant_emotion'], (x, y+h+30), font, 2, (0, 0, 255), 2, cv2.LINE_4)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('anju2.jpeg')

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  7.11it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 23.391826642533943,
#    'disgust': 0.00010662542856552303,
#    'fear': 1.5432877488985361,
#    'happy': 0.10706557547264392,
#    'sad': 40.282545652086064,
#    'surprise': 0.002572647156555824,
#    'neutral': 34.67258695690787},
#   'dominant_emotion': 'sad',
#   'region': {'x': 82, 'y': 1006, 'w': 231, 'h': 231},
#   'age': 29,
#   'gender': {'Woman': 51.58650875091553, 'Man': 48.41349422931671},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 25.192272663116455,
#    'indian': 7.885967940092087,
#    'black': 7.650306820869446,
#    'white': 25.271528959274292,
#    'middle eastern': 15.273907780647278,
#    'latino hispanic': 18.726015090942383},
#   'dominant_race': 'white'}]

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)

#draw a rectangle around the faces
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w , y+h),(0,255,0),2)

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
# Clear the text overlay by re-reading the original image
img = cv2.imread('anju2.jpeg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)

#draw a rectangle around the faces
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w , y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions[0]['dominant_emotion'], (x, y+h+30), font, 2, (0, 0, 255), 2, cv2.LINE_4)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
